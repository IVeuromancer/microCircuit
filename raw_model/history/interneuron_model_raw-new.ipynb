# %%
import neuron
from neuron import h
from neuron.units import ms, mV
import matplotlib.pyplot as plt
import numpy as np

# %%
h.load_file("cAD_ltb.hoc")
# Out:
# 1.0

# %%
morphology_dir = "morphologies"
morphology_name = "TC_jy160728_A_idA.asc"
TCcAD = h.cAD_ltb(morphology_dir, morphology_name)

# %%
IN_morphology_name = "IN_jy190506_A_idC.asc"
IN = h.cAD_ltb(morphology_dir, IN_morphology_name)

# %%
h.topology()
# Out:
# |-|       cAD_ltb[0].soma[0](0-1)
#    `|       cAD_ltb[0].axon[0](0-1)
#      `|       cAD_ltb[0].axon[1](0-1)
#   `|       cAD_ltb[0].dend[0](0-1)
#     `|       cAD_ltb[0].dend[1](0-1)
#       `----|       cAD_ltb[0].dend[2](0-1)
#             `--|       cAD_ltb[0].dend[3](0-1)
#             `--|       cAD_ltb[0].dend[4](0-1)
#       `|       cAD_ltb[0].dend[5](0-1)
#     `|       cAD_ltb[0].dend[6](0-1)
#       `------|       cAD_ltb[0].dend[7](0-1)
#       `--|       cAD_ltb[0].dend[8](0-1)
#   `|       cAD_ltb[0].dend[9](0-1)
#     `|       cAD_ltb[0].dend[10](0-1)
#       `|       cAD_ltb[0].dend[11](0-1)
#         `|       cAD_ltb[0].dend[12](0-1)
#           `|       cAD_ltb[0].dend[13](0-1)
#             `--|       cAD_ltb[0].dend[14](0-1)
#                 `----|       cAD_ltb[0].dend[15](0-1)
#                 `|       cAD_ltb[0].dend[16](0-1)
#                   `--|       cAD_ltb[0].dend[17](0-1)
#                   `----|       cAD_ltb[0].dend[18](0-1)
#             `|       cAD_ltb[0].dend[19](0-1)
#               `------|       cAD_ltb[0].dend[20](0-1)
#               `----|       cAD_ltb[0].dend[21](0-1)
#           `|       cAD_ltb[0].dend[22](0-1)
#             `|       cAD_ltb[0].dend[23](0-1)
#             `|       cAD_ltb[0].dend[24](0-1)
#               `----|       cAD_ltb[0].dend[25](0-1)
#               `|       cAD_ltb[0].dend[26](0-1)
#         `------|       cAD_ltb[0].dend[27](0-1)
#       `----|       cAD_ltb[0].dend[28](0-1)
#     `|       cAD_ltb[0].dend[29](0-1)
#       `|       cAD_ltb[0].dend[30](0-1)
#         `--|       cAD_ltb[0].dend[31](0-1)
#         `----|       cAD_ltb[0].dend[32](0-1)
#       `|       cAD_ltb[0].dend[33](0-1)
#         `----|       cAD_ltb[0].dend[34](0-1)
#         `--|       cAD_ltb[0].dend[35](0-1)
#   `|       cAD_ltb[0].dend[36](0-1)
#     `|       cAD_ltb[0].dend[37](0-1)
#       `|       cAD_ltb[0].dend[38](0-1)
#         `|       cAD_ltb[0].dend[39](0-1)
#           `|       cAD_ltb[0].dend[40](0-1)
#             `|       cAD_ltb[0].dend[41](0-1)
#               `----|       cAD_ltb[0].dend[42](0-1)
#               `------|       cAD_ltb[0].dend[43](0-1)
#             `----|       cAD_ltb[0].dend[44](0-1)
#           `----|       cAD_ltb[0].dend[45](0-1)
#         `|       cAD_ltb[0].dend[46](0-1)
#           `|       cAD_ltb[0].dend[47](0-1)
#             `|       cAD_ltb[0].dend[48](0-1)
#               `|       cAD_ltb[0].dend[49](0-1)
#                 `----|       cAD_ltb[0].dend[50](0-1)
#                 `----|       cAD_ltb[0].dend[51](0-1)
#               `----|       cAD_ltb[0].dend[52](0-1)
#             `----|       cAD_ltb[0].dend[53](0-1)
#           `--|       cAD_ltb[0].dend[54](0-1)
#       `|       cAD_ltb[0].dend[55](0-1)
#         `|       cAD_ltb[0].dend[56](0-1)
#           `|       cAD_ltb[0].dend[57](0-1)
#             `|       cAD_ltb[0].dend[58](0-1)
#               `|       cAD_ltb[0].dend[59](0-1)
#                 `|       cAD_ltb[0].dend[60](0-1)
#                   `------|       cAD_ltb[0].dend[61](0-1)
#                   `----|       cAD_ltb[0].dend[62](0-1)
#                 `----|       cAD_ltb[0].dend[63](0-1)
#               `----|       cAD_ltb[0].dend[64](0-1)
#             `----|       cAD_ltb[0].dend[65](0-1)
#           `----|       cAD_ltb[0].dend[66](0-1)
#         `----|       cAD_ltb[0].dend[67](0-1)
#     `|       cAD_ltb[0].dend[68](0-1)
#       `|       cAD_ltb[0].dend[69](0-1)
#         `--|       cAD_ltb[0].dend[70](0-1)
#         `--|       cAD_ltb[0].dend[71](0-1)
#       `|       cAD_ltb[0].dend[72](0-1)
#         `--|       cAD_ltb[0].dend[73](0-1)
#         `|       cAD_ltb[0].dend[74](0-1)
#   `|       cAD_ltb[0].dend[75](0-1)
#     `|       cAD_ltb[0].dend[76](0-1)
#       `|       cAD_ltb[0].dend[77](0-1)
#         `|       cAD_ltb[0].dend[78](0-1)
#           `--|       cAD_ltb[0].dend[79](0-1)
#           `|       cAD_ltb[0].dend[80](0-1)
#             `------|       cAD_ltb[0].dend[81](0-1)
#             `----|       cAD_ltb[0].dend[82](0-1)
#         `|       cAD_ltb[0].dend[83](0-1)
#           `|       cAD_ltb[0].dend[84](0-1)
#             `----|       cAD_ltb[0].dend[85](0-1)
#             `----|       cAD_ltb[0].dend[86](0-1)
#           `--|       cAD_ltb[0].dend[87](0-1)
#       `|       cAD_ltb[0].dend[88](0-1)
#     `|       cAD_ltb[0].dend[89](0-1)
#   `|       cAD_ltb[0].dend[90](0-1)
#     `|       cAD_ltb[0].dend[91](0-1)
#       `|       cAD_ltb[0].dend[92](0-1)
#         `|       cAD_ltb[0].dend[93](0-1)
#           `--|       cAD_ltb[0].dend[94](0-1)
#               `--|       cAD_ltb[0].dend[95](0-1)
#               `----|       cAD_ltb[0].dend[96](0-1)
#           `--|       cAD_ltb[0].dend[97](0-1)
#         `|       cAD_ltb[0].dend[98](0-1)
#           `|       cAD_ltb[0].dend[99](0-1)
#             `|       cAD_ltb[0].dend[100](0-1)
#               `|       cAD_ltb[0].dend[101](0-1)
#                 `------|       cAD_ltb[0].dend[102](0-1)
#                 `----|       cAD_ltb[0].dend[103](0-1)
#               `|       cAD_ltb[0].dend[104](0-1)
#                 `|       cAD_ltb[0].dend[105](0-1)
#                   `|       cAD_ltb[0].dend[106](0-1)
#                     `--|       cAD_ltb[0].dend[107](0-1)
#                     `--|       cAD_ltb[0].dend[108](0-1)
#                   `----|       cAD_ltb[0].dend[109](0-1)
#                 `----|       cAD_ltb[0].dend[110](0-1)
#             `|       cAD_ltb[0].dend[111](0-1)
#               `----|       cAD_ltb[0].dend[112](0-1)
#               `|       cAD_ltb[0].dend[113](0-1)
#                 `----|       cAD_ltb[0].dend[114](0-1)
#                 `----|       cAD_ltb[0].dend[115](0-1)
#           `----|       cAD_ltb[0].dend[116](0-1)
#       `|       cAD_ltb[0].dend[117](0-1)
#         `--|       cAD_ltb[0].dend[118](0-1)
#         `--|       cAD_ltb[0].dend[119](0-1)
#     `|       cAD_ltb[0].dend[120](0-1)
#       `------|       cAD_ltb[0].dend[121](0-1)
#       `----|       cAD_ltb[0].dend[122](0-1)
#   `|       cAD_ltb[0].dend[123](0-1)
#     `|       cAD_ltb[0].dend[124](0-1)
#       `|       cAD_ltb[0].dend[125](0-1)
#         `|       cAD_ltb[0].dend[126](0-1)
#           `|       cAD_ltb[0].dend[127](0-1)
#             `|       cAD_ltb[0].dend[128](0-1)
#               `|       cAD_ltb[0].dend[129](0-1)
#                 `----|       cAD_ltb[0].dend[130](0-1)
#                 `------|       cAD_ltb[0].dend[131](0-1)
#               `|       cAD_ltb[0].dend[132](0-1)
#                 `----|       cAD_ltb[0].dend[133](0-1)
#                 `--|       cAD_ltb[0].dend[134](0-1)
#             `|       cAD_ltb[0].dend[135](0-1)
#               `|       cAD_ltb[0].dend[136](0-1)
#                 `----|       cAD_ltb[0].dend[137](0-1)
#                 `----|       cAD_ltb[0].dend[138](0-1)
#               `|       cAD_ltb[0].dend[139](0-1)
#                 `----|       cAD_ltb[0].dend[140](0-1)
#           `|       cAD_ltb[0].dend[141](0-1)
#             `|       cAD_ltb[0].dend[142](0-1)
#               `|       cAD_ltb[0].dend[143](0-1)
#                 `--|       cAD_ltb[0].dend[144](0-1)
#                 `----|       cAD_ltb[0].dend[145](0-1)
#               `--|       cAD_ltb[0].dend[146](0-1)
#             `|       cAD_ltb[0].dend[147](0-1)
#               `|       cAD_ltb[0].dend[148](0-1)
#                 `----|       cAD_ltb[0].dend[149](0-1)
#                 `----|       cAD_ltb[0].dend[150](0-1)
#               `--|       cAD_ltb[0].dend[151](0-1)
#         `|       cAD_ltb[0].dend[152](0-1)
#           `------|       cAD_ltb[0].dend[153](0-1)
#           `|       cAD_ltb[0].dend[154](0-1)
#             `----|       cAD_ltb[0].dend[155](0-1)
#             `|       cAD_ltb[0].dend[156](0-1)
#               `--|       cAD_ltb[0].dend[157](0-1)
#               `|       cAD_ltb[0].dend[158](0-1)
#       `|       cAD_ltb[0].dend[159](0-1)
#         `|       cAD_ltb[0].dend[160](0-1)
#           `|       cAD_ltb[0].dend[161](0-1)
#             `------|       cAD_ltb[0].dend[162](0-1)
#             `------|       cAD_ltb[0].dend[163](0-1)
#           `------|       cAD_ltb[0].dend[164](0-1)
#         `----|       cAD_ltb[0].dend[165](0-1)
#     `----|       cAD_ltb[0].dend[166](0-1)
#   `|       cAD_ltb[0].dend[167](0-1)
#     `|       cAD_ltb[0].dend[168](0-1)
#       `|       cAD_ltb[0].dend[169](0-1)
#         `|       cAD_ltb[0].dend[170](0-1)
#           `----|       cAD_ltb[0].dend[171](0-1)
#           `----|       cAD_ltb[0].dend[172](0-1)
#         `|       cAD_ltb[0].dend[173](0-1)
#           `|       cAD_ltb[0].dend[174](0-1)
#           `|       cAD_ltb[0].dend[175](0-1)
#       `|       cAD_ltb[0].dend[176](0-1)
#         `|       cAD_ltb[0].dend[177](0-1)
#           `--|       cAD_ltb[0].dend[178](0-1)
#               `----|       cAD_ltb[0].dend[179](0-1)
#               `----|       cAD_ltb[0].dend[180](0-1)
#           `--------|       cAD_ltb[0].dend[181](0-1)
#         `|       cAD_ltb[0].dend[182](0-1)
#     `|       cAD_ltb[0].dend[183](0-1)
#       `----|       cAD_ltb[0].dend[184](0-1)
#       `--|       cAD_ltb[0].dend[185](0-1)
#           `|       cAD_ltb[0].dend[186](0-1)
#           `|       cAD_ltb[0].dend[187](0-1)
#   `--|       cAD_ltb[0].dend[188](0-1)
#       `|       cAD_ltb[0].dend[189](0-1)
#         `|       cAD_ltb[0].dend[190](0-1)
#           `|       cAD_ltb[0].dend[191](0-1)
#             `----|       cAD_ltb[0].dend[192](0-1)
#             `----|       cAD_ltb[0].dend[193](0-1)
#           `----|       cAD_ltb[0].dend[194](0-1)
#         `----|       cAD_ltb[0].dend[195](0-1)
#       `----|       cAD_ltb[0].dend[196](0-1)
#   `|       cAD_ltb[0].dend[197](0-1)
#     `|       cAD_ltb[0].dend[198](0-1)
#       `|       cAD_ltb[0].dend[199](0-1)
#         `--|       cAD_ltb[0].dend[200](0-1)
#             `|       cAD_ltb[0].dend[201](0-1)
#               `--|       cAD_ltb[0].dend[202](0-1)
#               `--|       cAD_ltb[0].dend[203](0-1)
#             `----|       cAD_ltb[0].dend[204](0-1)
#         `|       cAD_ltb[0].dend[205](0-1)
#           `------|       cAD_ltb[0].dend[206](0-1)
#           `------|       cAD_ltb[0].dend[207](0-1)
#       `----|       cAD_ltb[0].dend[208](0-1)
#     `----|       cAD_ltb[0].dend[209](0-1)
#           `--|       cAD_ltb[0].dend[210](0-1)
#           `|       cAD_ltb[0].dend[211](0-1)
#   `|       cAD_ltb[0].dend[212](0-1)
#     `|       cAD_ltb[0].dend[213](0-1)
#     `|       cAD_ltb[0].dend[214](0-1)
# |-|       cAD_ltb[1].soma[0](0-1)
#    `|       cAD_ltb[1].axon[0](0-1)
#      `|       cAD_ltb[1].axon[1](0-1)
#   `|       cAD_ltb[1].dend[0](0-1)
#     `|       cAD_ltb[1].dend[1](0-1)
#       `|       cAD_ltb[1].dend[2](0-1)
#       `|       cAD_ltb[1].dend[3](0-1)
#     `|       cAD_ltb[1].dend[4](0-1)
#       `--|       cAD_ltb[1].dend[5](0-1)
#           `|       cAD_ltb[1].dend[6](0-1)
#           `------|       cAD_ltb[1].dend[7](0-1)
#       `----|       cAD_ltb[1].dend[8](0-1)
#   `|       cAD_ltb[1].dend[9](0-1)
#     `|       cAD_ltb[1].dend[10](0-1)
#       `|       cAD_ltb[1].dend[11](0-1)
#         `|       cAD_ltb[1].dend[12](0-1)
#           `--------------|       cAD_ltb[1].dend[13](0-1)
#           `----|       cAD_ltb[1].dend[14](0-1)
#         `--|       cAD_ltb[1].dend[15](0-1)
#       `|       cAD_ltb[1].dend[16](0-1)
#         `--------|       cAD_ltb[1].dend[17](0-1)
#         `--|       cAD_ltb[1].dend[18](0-1)
#     `--|       cAD_ltb[1].dend[19](0-1)
#   `|       cAD_ltb[1].dend[20](0-1)
# 1.0

# %%
import neurom
import neurom.viewer
TCcAD_morph_path = 'C:/Users/yijan/OneDrive/Desktop/Interneuron_model/raw_model/morphologies/TC_jy160728_A_idA.asc'
IN_morph_path = 'C:/Users/yijan/OneDrive/Desktop/Interneuron_model/raw_model/morphologies/IN_jy190506_A_idC.asc'
morph_TCcAD = neurom.load_neuron(TCcAD_morph_path)
morph_IN = neurom.load_neuron(IN_morph_path)
# Out:
# C:\Users\yijan\anaconda3\lib\site-packages\neurom\io\neurolucida.py:266: UserWarning: This is an experimental reader. There are no guarantees regarding ability to parse Neurolucida .asc files or correctness of output.
#   warnings.warn('This is an experimental reader. '

# %%
'''
# %matplotlib notebook
neurom.viewer.draw(morph_TCcAD, mode = '3d')
neurom.viewer.draw(morph_IN, mode = '3d')
'''

# %matplotlib inline
neurom.viewer.draw(morph_TCcAD, mode = 'dendrogram')
neurom.viewer.draw(morph_IN, mode = 'dendrogram')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x24c6e990508>)

# %%
class Cell:
    def __init__(self, gid, x, y, z, theta):
        self._gid = gid
        self._setup_cell()
        self.x = self.y = self.z = 0                     
        h.define_shape()
        self._rotate_z(theta)                                   
        self._set_position(x, y, z)                      
        
    def __repr__(self):
        return '{}[{}]'.format(self.name, self._gid)
    
    def _set_position(self, x, y, z):
        for sec in self.model.all:
            for i in range(sec.n3d()):
                sec.pt3dchange(i,
                               x - self.x + sec.x3d(i),
                               y - self.y + sec.y3d(i),
                               z - self.z + sec.z3d(i),
                              sec.diam3d(i))
        self.x, self.y, self.z = x, y, z
    def _rotate_z(self, theta):
        """Rotate the cell about the Z axis."""
        for sec in self.model.all:
            for i in range(sec.n3d()):
                x = sec.x3d(i)
                y = sec.y3d(i)
                c = h.cos(theta)
                s = h.sin(theta)
                xprime = x * c - y * s
                yprime = x * s + y * c
                sec.pt3dchange(i, xprime, yprime, sec.z3d(i), sec.diam3d(i))
    
class IN(Cell):
    name = 'Interneuron'
    def _setup_cell(self):
        h.load_file("cAD_ltb.hoc")
        morphology_dir = "morphologies"
        morphology_name = "IN_jy190506_A_idC.asc"
        self.model = h.cAD_ltb(morphology_dir, morphology_name)

class TC(Cell):
    name = 'TC'
    def _setup_cell(self):
        h.load_file("cAD_ltb.hoc")
        morphology_dir = "morphologies"
        morphology_name = "TC_jy160728_A_idA.asc"
        self.model = h.cAD_ltb(morphology_dir, morphology_name)

# %%
TC_1 = TC(0,50,50,50,90)

# %%
stim = h.IClamp(TC_1.model.soma[0](0.5))
stim.dur   = 200
stim.delay = 200
stim.amp   = 0.250

# %%
t = h.Vector()
t.record(h._ref_t)

soma_v = h.Vector()
soma_v.record(TC_1.model.soma[0](0.5)._ref_v)

dend_v = h.Vector()
dend_v.record(TC_1.model.dend[18](0.5)._ref_v)


stim_current = h.Vector()
stim_current.record(stim._ref_i);

# %%
#h.finitialize(-79 * mV) what is the difference?
h.v_init = -79
h.tstop = 500
h.celsius = 34
h.run();

# %%
f, (ax0, ax1) = plt.subplots(2,1, figsize=(5,4), gridspec_kw = {'height_ratios':[3, 1]})
ax0.plot(t,soma_v, 'k', label = 'soma')
ax0.plot(t,dend_v, 'orange', label = 'dend[18]')
ax0.legend(frameon=False)
ax1.plot(t,stim_current)

ax0.set_ylabel('Voltage (mV)')
#ax0.set_ylim(-80,20)
ax0.spines['right'].set_visible(False)
ax0.spines['top'].set_visible(False)
ax0.spines['bottom'].set_visible(False)
ax0.get_xaxis().set_visible(False)


ax1.plot([50,50],[0.1,0.35],'k')
ax1.text(80,0.2,'250 pA',va='center')
ax1.set_ylabel('I (nA)')
ax1.set_xlabel('t (ms)')
#ax1.set_ylim(-0.01,0.02)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.get_yaxis().set_visible(False)
plt.tight_layout()

# %%
def create_n_TC(n, r):
    """n = number of cells; r = radius of circle"""
    cells = []
    for i in range(n):
        theta = i * 2 * h.PI / n
        cells.append(TC(i, h.cos(theta) * r, h.sin(theta) * r, 0, theta))
    return cells

# %%
all_TCs = create_n_TC(5,100)

# %%
IN_1 = IN(0,0,0,0,0)

# %%
ps = h.PlotShape(True)
ps.show(0)
# Out:
# 1.0

# %%
stim = h.NetStim() # Make a new stimulator

# Attach it to a synapse in the middle of the dendrite
# of the first cell in the network. (Named 'syn_' to avoid
# being overwritten with the 'syn' var assigned later.)
syn_oc_Br_to_oc_IN_prox = h.ExpSyn(IN_1.model.dend[0](0.1))
syn_oc_Br_to_oc_IN_dist = h.ExpSyn(IN_1.model.dend[13](0.9))
syn_oc_Br_to_oc_TC0 = h.ExpSyn(all_TCs[0].model.dend[0](0.1))
syn_oc_Br_to_oc_TC1 = h.ExpSyn(all_TCs[1].model.dend[0](0.1))
syn_oc_Br_to_oc_TC2 = h.ExpSyn(all_TCs[2].model.dend[0](0.1))
syn_oc_Br_to_oc_TC3 = h.ExpSyn(all_TCs[3].model.dend[0](0.1))
syn_oc_Br_to_oc_TC4 = h.ExpSyn(all_TCs[4].model.dend[0](0.1))


stim.number = 1
stim.start = 9

ncstim_IN_prox = h.NetCon(stim, syn_oc_Br_to_oc_IN_prox)
ncstim_IN_prox.delay = 1 * ms
ncstim_IN_prox.weight[0] = 0.04 # NetCon weight is a vector.
syn_oc_Br_to_oc_IN_prox.tau = 3 * ms

ncstim_IN_dist = h.NetCon(stim, syn_oc_Br_to_oc_IN_dist)
ncstim_IN_dist.delay = 1 * ms
ncstim_IN_dist.weight[0] = 0.04 # NetCon weight is a vector.
syn_oc_Br_to_oc_IN_dist.tau = 2 * ms

ncstim_TC0 = h.NetCon(stim, syn_oc_Br_to_oc_TC0)
ncstim_TC0.delay = 1 * ms
ncstim_TC0.weight[0] = 0.04 # NetCon weight is a vector. 
syn_oc_Br_to_oc_TC0.tau = 2 * ms

ncstim_TC1 = h.NetCon(stim, syn_oc_Br_to_oc_TC1)
ncstim_TC1.delay = 1 * ms
ncstim_TC1.weight[0] = 0.04 # NetCon weight is a vector.
syn_oc_Br_to_oc_TC1.tau = 2 * ms

ncstim_TC2 = h.NetCon(stim, syn_oc_Br_to_oc_TC2)
ncstim_TC2.delay = 1 * ms
ncstim_TC2.weight[0] = 0.04 # NetCon weight is a vector. 
syn_oc_Br_to_oc_TC2.tau = 2 * ms

ncstim_TC3 = h.NetCon(stim, syn_oc_Br_to_oc_TC3)
ncstim_TC3.delay = 1 * ms
ncstim_TC3.weight[0] = 0.04 # NetCon weight is a vector.
syn_oc_Br_to_oc_TC3.tau = 2 * ms

ncstim_TC4 = h.NetCon(stim, syn_oc_Br_to_oc_TC4)
ncstim_TC4.delay = 1 * ms
ncstim_TC4.weight[0] = 0.04 # NetCon weight is a vector.
syn_oc_Br_to_oc_TC4.tau = 2 * ms

# %%
print('Reversal potential = {} mV'.format(syn_oc_Br_to_oc_IN_prox.e))
# Out:
# Reversal potential = 0.0 mV

# %%
IN_soma_v = h.Vector().record(IN_1.model.soma[0](0.5)._ref_v)
IN_dend_prox_v = h.Vector().record(IN_1.model.dend[0](0.1)._ref_v)
IN_dend_dist_v = h.Vector().record(IN_1.model.dend[13](0.9)._ref_v)

TC_soma_v = h.Vector().record(all_TCs[0].model.soma[0](0.5)._ref_v)
TC_dend_v = h.Vector().record(all_TCs[0].model.dend[0](0.1)._ref_v)

t = h.Vector().record(h._ref_t)

# %%
h.v_init = -65
h.tstop = 50
h.celsius = 34
h.run();

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(2, 1, 1)
IN_soma_plot = ax1.plot(t, IN_soma_v, color='black', label='IN_1.model.soma[0](0.5)')
IN_dend_prox_plot = ax1.plot(t, IN_dend_prox_v, color='grey', label='IN_1.model.dend[0](0.1)')
IN_dend_dist_plot = ax1.plot(t, IN_dend_dist_v, color='red', label='IN_1.model.dend[13](0.9)')
ax1.legend()
ax1.set_ylabel('mV')
ax1.set_xticks([]) # Use ax2's tick labels

ax2 = fig.add_subplot(2, 1, 2)
TC_soma_plot = ax2.plot(t, TC_soma_v, color='black', label='all_TCs[0].model.soma[0](0.5)')
TC_dend_plot = ax2.plot(t, TC_dend_v, color='grey', label='all_TCs[0].model.dend[0](0.1)')
ax2.legend()
ax2.set_ylabel('mV')
ax2.set_xlabel('time (ms)')
plt.show()

# %%
syn_oc_Br_to_oc_IN_prox_i = h.Vector().record(syn_oc_Br_to_oc_IN_prox._ref_i)

# %%
h.v_init = -65
h.tstop = 50
h.celsius = 34
h.run();

# %%
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(2, 1, 1)
IN_soma_plot = ax1.plot(t, IN_soma_v, color='black', label='IN_1.model.soma[0](0.5)')
IN_dend_prox_plot = ax1.plot(t, IN_dend_prox_v, color='grey', label='IN_1.model.dend[0](0.1)')
IN_dend_dist_plot = ax1.plot(t, IN_dend_dist_v, color='red', label='IN_1.model.dend[13](0.9)')
rev_plot = ax1.plot([t[0], t[-1]], [syn_oc_Br_to_oc_IN_prox.e, syn_oc_Br_to_oc_IN_prox.e], label='syn reversal',
        color='blue', linestyle=':')
ax1.legend()
ax1.set_ylabel('mV')
ax1.set_xticks([]) # Use ax2's tick labels

ax2 = fig.add_subplot(2, 1, 2)
syn_oc_Br_to_oc_IN_prox_plot = ax2.plot(t, syn_oc_Br_to_oc_IN_prox_i, color='black', label='synaptic current')
ax2.legend()
ax2.set_ylabel(h.units('ExpSyn.i'))
ax2.set_xlabel('time (ms)')
plt.show()

# %%
syns = []
netcons = []
for target in all_TCs:
    syn = h.Exp2Syn(target.model.dend[0](0.1))
    nc = h.NetCon(IN_1.model.soma[0](0.5)._ref_v, syn, sec=IN_1.model.soma[0])
    nc.weight[0] = 0.04
    nc.delay = 1
    syn.tau1 = 0.7
    syn.tau2 = 4.2
    syn.e = -80
    netcons.append(nc)
    syns.append(syn)
    
    
    
syns2 = []
netcons2 = []
for target in all_TCs:
    syn2 = h.Exp2Syn(target.model.dend[0](0.1))
    nc2 = h.NetCon(IN_1.model.dend[13](0.9)._ref_v, syn2, sec=IN_1.model.dend[13])
    nc2.weight[0] = 0.04
    nc2.delay = 0.5
    nc2.threshold = -15
    syn2.tau1 = 0.7
    syn2.tau2 = 4.2
    syn2.e = -80
    netcons2.append(nc2)
    syns2.append(syn2)

# %%
IN_soma_v = h.Vector().record(IN_1.model.soma[0](0.5)._ref_v)
IN_dend_prox_v = h.Vector().record(IN_1.model.dend[0](0.1)._ref_v)
IN_dend_dist_v = h.Vector().record(IN_1.model.dend[13](0.9)._ref_v)

TC0_soma_v = h.Vector().record(all_TCs[0].model.soma[0](0.5)._ref_v)
TC0_dend_v = h.Vector().record(all_TCs[0].model.dend[0](0.1)._ref_v)

TC1_soma_v = h.Vector().record(all_TCs[1].model.soma[0](0.5)._ref_v)
TC1_dend_v = h.Vector().record(all_TCs[1].model.dend[0](0.1)._ref_v)

TC2_soma_v = h.Vector().record(all_TCs[2].model.soma[0](0.5)._ref_v)
TC2_dend_v = h.Vector().record(all_TCs[2].model.dend[0](0.1)._ref_v)

TC3_soma_v = h.Vector().record(all_TCs[3].model.soma[0](0.5)._ref_v)
TC3_dend_v = h.Vector().record(all_TCs[3].model.dend[0](0.1)._ref_v)

TC4_soma_v = h.Vector().record(all_TCs[4].model.soma[0](0.5)._ref_v)
TC4_dend_v = h.Vector().record(all_TCs[4].model.dend[0](0.1)._ref_v)

t = h.Vector().record(h._ref_t)
'''
h.finitialize(-65 * mV)
h.continuerun(100 * ms)
'''

h.v_init = -65
h.tstop = 100
h.celsius = 34
h.run();

# %%
# %matplotlib inline
fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(6, 1, 1)
IN_soma_plot = ax1.plot(t, IN_soma_v, color='black', label='IN_1.model.soma[0](0.5)')
IN_dend_prox_plot = ax1.plot(t, IN_dend_prox_v, color='grey', label='IN_1.model.dend[0](0.1)')
IN_dend_dist_plot = ax1.plot(t, IN_dend_dist_v, color='red', label='IN_1.model.dend[13](0.9)')
ax1.legend()
ax1.set_ylabel('mV')
ax1.set_xticks([]) # Use ax2's tick labels

ax2 = fig.add_subplot(6, 1, 2)
TC0_soma_plot = ax2.plot(t, TC0_soma_v, color='black', label='all_TCs[0].model.soma[0](0.5)')
TC0_dend_plot = ax2.plot(t, TC0_dend_v, color= 'grey', label='all_TCs[0].model.dend[0](0.1)')
ax2.legend()
ax2.set_ylabel('mV')
ax2.set_xticks([])

ax3 = fig.add_subplot(6,1,3)
TC1_soma_plot = ax3.plot(t, TC1_soma_v, color='black', label='all_TCs[1].model.soma[0](0.5)')
TC1_dend_plot = ax3.plot(t, TC1_dend_v, color= 'grey', label='all_TCs[1].model.dend[0](0.1)')
ax3.legend()
ax3.set_ylabel('mV')
ax3.set_xticks([])

ax4 = fig.add_subplot(6,1,4)
TC2_soma_plot = ax4.plot(t, TC2_soma_v, color='black', label='all_TCs[2].model.soma[0](0.5)')
TC2_dend_plot = ax4.plot(t, TC2_dend_v, color= 'grey', label='all_TCs[2].model.dend[0](0.1)')
ax4.legend()
ax4.set_ylabel('mV')
ax4.set_xticks([])

ax5 = fig.add_subplot(6,1,5)
TC3_soma_plot = ax5.plot(t, TC3_soma_v, color='black', label='all_TCs[3].model.soma[0](0.5)')
TC3_dend_plot = ax5.plot(t, TC3_dend_v, color= 'grey', label='all_TCs[3].model.dend[0](0.1)')
ax5.legend()
ax5.set_ylabel('mV')
ax5.set_xticks([])

ax6 = fig.add_subplot(6,1,6)
TC4_soma_plot = ax6.plot(t, TC4_soma_v, color='black', label='all_TCs[4].model.soma[0](0.5)')
TC4_dend_plot = ax6.plot(t, TC4_dend_v, color= 'grey', label='all_TCs[4].model.dend[0](0.1)')
ax6.legend()
ax6.set_ylabel('mV')
ax6.set_xlabel('time (ms)')
plt.show()

# %%
spike_times = [h.Vector() for nc in netcons]
for nc, spike_times_vec in zip(netcons, spike_times):
    nc.record(spike_times_vec)
    
release_times = [h.Vector() for nc2 in netcons2]
for nc2, release_times_vec in zip(netcons2, release_times):
    nc2.record(release_times_vec)

# %%
'''
h.finitialize(-65 * mV)
h.continuerun(100 * ms)

'''
h.v_init = -65
h.tstop = 100
h.celsius = 34
h.run();
# Out:
# 0.0

# %%
for i, spike_times_vec in enumerate(spike_times):
    print('TC {}: {}'.format(i, list(spike_times_vec)))
    
for k, release_times_vec in enumerate(release_times):
    print('TC {}: {}'.format(k, list(release_times_vec)))
# Out:
# TC 0: []
# TC 1: []
# TC 2: []
# TC 3: []
# TC 4: [10.600000000099932, 18.40000000009949]
# TC 0: []
# TC 1: []
# TC 2: []
# TC 3: []
# TC 4: [10.025000000099965, 27.225000000098987, 33.275000000099006, 38.775000000100256, 44.15000000010148, 50.35000000010289, 56.02500000010418, 62.300000000105605, 67.92500000010688, 73.47500000010814, 78.92500000010938, 84.77500000011071, 90.30000000011196, 96.12500000011329]

# %%
plt.figure()

plt.vlines(release_times_vec, 3, 2)
plt.show()

# %%
class Cell:
    def __init__(self, gid, x, y, z, theta):
        self._gid = gid
        self._setup_cell()
        self.x = self.y = self.z = 0                     
        h.define_shape()
        self._rotate_z(theta)                                   
        self._set_position(x, y, z)  
        
        # record spikes, soma/prox-dend from all cells
        self._spike_detector = h.NetCon(self.model.soma[0](0.5)._ref_v, None, sec=self.model.soma[0])
        self.spike_times = h.Vector()
        self._spike_detector.record(self.spike_times)
        self.soma_v = h.Vector().record(self.model.soma[0](0.5)._ref_v)
        self.dend_prox_v = h.Vector().record(self.model.dend[0](0.1)._ref_v)
        
    def __repr__(self):
        return '{}[{}]'.format(self.name, self._gid)
    
    def _set_position(self, x, y, z):
        for sec in self.model.all:
            for i in range(sec.n3d()):
                sec.pt3dchange(i,
                               x - self.x + sec.x3d(i),
                               y - self.y + sec.y3d(i),
                               z - self.z + sec.z3d(i),
                              sec.diam3d(i))
        self.x, self.y, self.z = x, y, z
    def _rotate_z(self, theta):
        """Rotate the cell about the Z axis."""
        for sec in self.model.all:
            for i in range(sec.n3d()):
                x = sec.x3d(i)
                y = sec.y3d(i)
                c = h.cos(theta)
                s = h.sin(theta)
                xprime = x * c - y * s
                yprime = x * s + y * c
                sec.pt3dchange(i, xprime, yprime, sec.z3d(i), sec.diam3d(i))
    
class IN(Cell):
    name = 'Interneuron'
    def _setup_cell(self):
        h.load_file("cAD_ltb.hoc")
        morphology_dir = "morphologies"
        morphology_name = "IN_jy190506_A_idC.asc"
        self.model = h.cAD_ltb(morphology_dir, morphology_name)
        
        # contains all spike detectors
        self.ncs = []

        # recording of release events in distal dendrites
        self._release_detector = h.NetCon(self.model.dend[13](0.9)._ref_v, None, sec=self.model.dend[13])
        self.release_times = h.Vector()
        self._release_detector.record(self.release_times)
        # contains all release detectors
        self.ncs2 = []
        self.dend_dist_v = h.Vector().record(self.model.dend[13](0.9)._ref_v)
        
        # add synapses received from brainstem Br
        self.syn_Brprox = h.ExpSyn(self.model.dend[0](0.1))
        self.syn_Brprox.tau = 3 * ms
        
        self.syn_Brdist = h.ExpSyn(self.model.dend[13](0.9))
        self.syn_Brdist.tau = 2 * ms
        

class TC(Cell):
    name = 'TC'
    def _setup_cell(self):
        h.load_file("cAD_ltb.hoc")
        morphology_dir = "morphologies"
        morphology_name = "TC_jy160728_A_idA.asc"
        self.model = h.cAD_ltb(morphology_dir, morphology_name)
        
        # add synapses received from brainstem Br
        self.syn_Br = h.ExpSyn(self.model.dend[0](0.1))
        self.syn_Br.tau = 2 * ms
        
        # add synapses received from IN
        self.syn_INaxonal = h.Exp2Syn(self.model.dend[0](0.1))
        self.syn_INaxonal.tau1 = 0.7
        self.syn_INaxonal.tau2 = 4.2
        self.syn_INaxonal.e = -80
        
        self.syn_INdendritic = h.Exp2Syn(self.model.dend[0](0.1))
        self.syn_INdendritic.tau1 = 0.7
        self.syn_INdendritic.tau2 = 4.2
        self.syn_INdendritic.e = -80

# %%
class Ring:
    """
    A network of TC and IN cells where IN makes an
    axonal and dendritic synapse onto all other TCs and all cells 
    receive Br input
    
    """
    def __init__(self, N=5, r=100):
        """
        :param N: Number of cells. 5 by default
        :param r: radius of the network. 100um by default

        """ 
        # Add Br spikes 
        self._netstim = h.NetStim()
        self._netstim.number = 1
        self._netstim.start = 9
        self.ncBrs = []
        
        # create TCs and IN
        self._create_cells(N, r)
        # create spike detectors from IN and Br to looped TC targets
        self._add_IN_syn()
        self._add_Br_syn()
        
        # create spike detectors from Br for IN targets (prox and dist denrites)
        self.ncBr2 = h.NetCon(self._netstim, self.IN_1.syn_Brprox)
        self.ncBr2.weight[0] =0.04
        self.ncBr2.delay = 1

        self.ncBr3 = h.NetCon(self._netstim, self.IN_1.syn_Brdist)
        self.ncBr3.weight[0] =0.04
        self.ncBr3.delay = 1
        
    def _create_cells(self, N, r):
        self.TCcells = [] 
        self.IN_1 = IN(0,0,0,0,0)    
        for i in range(N):
            theta = i * 2 * h.PI / N
            self.TCcells.append(TC(i, h.cos(theta) * r, h.sin(theta) * r, 0, theta))
        
    def _add_IN_syn(self):
        for target in self.TCcells:
            self.nc = h.NetCon(self.IN_1.model.soma[0](0.5)._ref_v, target.syn_INaxonal, sec=self.IN_1.model.soma[0])
            self.nc.weight[0] = 0.04
            self.nc.delay = 1
            self.IN_1.ncs.append(self.nc)
    
        for target in self.TCcells:
            self.nc2 = h.NetCon(self.IN_1.model.dend[13](0.9)._ref_v, target.syn_INdendritic, sec=self.IN_1.model.dend[13])
            self.nc2.weight[0] = 0.04
            self.nc2.delay = 0.5
            self.nc2.threshold = -15 # threshold needs to be lower for distal dendritic release
            self.IN_1.ncs2.append(self.nc2)
            
    def _add_Br_syn(self):
        for target in self.TCcells:
            self.ncBr = h.NetCon(self._netstim, target.syn_Br)
            self.ncBr.weight[0] = 0.04
            self.ncBr.delay = 1
            self.ncBrs.append(self.ncBr)

# %%
ring = Ring()

# %%
shape_window = h.PlotShape(True)
shape_window.show(0)
# Out:
# 1.0

# %%
t = h.Vector().record(h._ref_t)

'''
h.finitialize(-65 * mV)
h.continuerun(100)
'''

h.v_init = -65
h.tstop = 100
h.celsius = 34
h.run();

# %%
# %matplotlib inline
fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(6, 1, 1)
IN_soma_plot = ax1.plot(t, ring.IN_1.soma_v, color='black', label='IN soma')
IN_dend_prox_plot = ax1.plot(t, ring.IN_1.dend_prox_v, color='grey', label='IN prox dend')
IN_dend_dist_plot = ax1.plot(t, ring.IN_1.dend_dist_v, color='red', label='IN dist dend')
ax1.legend(loc='upper right')
ax1.set_ylabel('mV')
ax1.set_xticks([]) # Use ax2's tick labels

ax2 = fig.add_subplot(6, 1, 2)
TC0_soma_plot = ax2.plot(t, ring.TCcells[0].soma_v, color='black', label='TC1 soma')
TC0_dend_plot = ax2.plot(t, ring.TCcells[0].dend_prox_v, color= 'grey', label='TC1 dend')
ax2.legend()
ax2.set_ylabel('mV')
ax2.set_xticks([])

ax3 = fig.add_subplot(6,1,3)
TC1_soma_plot = ax3.plot(t, ring.TCcells[1].soma_v, color='black', label='TC2 soma')
TC1_dend_plot = ax3.plot(t, ring.TCcells[1].dend_prox_v, color= 'grey', label='TC2 dend')
ax3.legend()
ax3.set_ylabel('mV')
ax3.set_xticks([])

ax4 = fig.add_subplot(6,1,4)
TC2_soma_plot = ax4.plot(t, ring.TCcells[2].soma_v, color='black', label='TC3 soma')
TC2_dend_plot = ax4.plot(t, ring.TCcells[2].dend_prox_v, color= 'grey', label='TC3 dend')
ax4.legend()
ax4.set_ylabel('mV')
ax4.set_xticks([])

ax5 = fig.add_subplot(6,1,5)
TC3_soma_plot = ax5.plot(t, ring.TCcells[3].soma_v, color='black', label='TC4 soma')
TC3_dend_plot = ax5.plot(t, ring.TCcells[3].dend_prox_v, color= 'grey', label='TC4 dend')
ax5.legend()
ax5.set_ylabel('mV')
ax5.set_xticks([])

ax6 = fig.add_subplot(6,1,6)
TC4_soma_plot = ax6.plot(t, ring.TCcells[4].soma_v, color='black', label='TC5 soma')
TC4_dend_plot = ax6.plot(t, ring.TCcells[4].dend_prox_v, color= 'grey', label='TC5 dend')
ax6.legend()
ax6.set_ylabel('mV')
ax6.set_xlabel('time (ms)')
plt.show()
